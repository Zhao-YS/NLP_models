# %%
from tqdm import tqdm
import torch.nn as nn
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Load and preprocess the data
with open('data/1268-0.txt', 'r', encoding="utf8") as file:
    corpus = file.read()
    
start_index = corpus.find('THE MYSTERIOUS ISLAND')
end_index = corpus.find('End of the Project Gutenberg')

corpus = corpus[start_index:end_index]
char_set = set(corpus)
print('Total Length:', len(corpus))
print('Unique Characters:', len(char_set))
assert(len(corpus) == 1130711)
assert(len(char_set) == 85)
# Out:
# Total Length: 1130711
# Unique Characters: 85

# %%
characters = sorted(char_set)

char_to_idx = {ch: i for i, ch in enumerate(characters)}
idx_to_char = np.array(characters)

# Tokenize the entire corpus.
encoded_corpus = np.array(
    [char_to_idx[ch] for ch in corpus],
    dtype=np.int32)

print('Text encoded shape: ', encoded_corpus.shape)
print(corpus[:15], '     == Encoding ==> ', encoded_corpus[:15])
print(encoded_corpus[15:21], ' == Reverse  ==> ', ''.join(idx_to_char[encoded_corpus[15:21]]))
# Out:
# Text encoded shape:  (1130711,)
# THE MYSTERIOUS       == Encoding ==>  [48 36 33  1 41 53 47 48 33 46 37 43 49 47  1]
# [37 47 40 29 42 32]  == Reverse  ==>  ISLAND

# %%
# Process the data and get the data loader

seq_length = 40
chunk_size = seq_length + 1

text_chunks = [encoded_corpus[i:i+chunk_size] for i in range(len(encoded_corpus)-chunk_size+1)]

# %%
class TextDataset(Dataset):
    def __init__(self, text_chunks):
        self.text_chunks = text_chunks

    def __len__(self):
        return len(self.text_chunks)
    
    def __getitem__(self, idx):
        text_chunk = self.text_chunks[idx]
        return text_chunk[:-1].long(), text_chunk[1:].long()

# %%
dataset = TextDataset(torch.tensor(text_chunks))
# Out:
# /var/folders/mx/41vmmjnx00z2pm2st2dnvjb40000gn/T/ipykernel_78735/4151818131.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   dataset = TextDataset(torch.tensor(text_chunks))

# %%
device = torch.device("cpu")
batch_size = 64
torch.manual_seed(1)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
# Define the models

class RNNModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, rnn_hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.rnn_hidden_size = rnn_hidden_size
        self.rnn = nn.LSTM(
            embed_dim,
            rnn_hidden_size,
            batch_first=True
        )
        self.fc = nn.Linear(rnn_hidden_size, vocab_size)

    def forward(self, text, hidden, cell):
        embedded_text = self.embedding(text)
        output, (hidden, cell) = self.rnn(embedded_text, (hidden, cell))
        output = self.fc(output)
        return output, (hidden, cell)

    def init_hidden(self, batch_size):
        hidden = torch.zeros(1, batch_size, self.rnn_hidden_size)
        cell = torch.zeros(1, batch_size, self.rnn_hidden_size)
        return hidden.to(device), cell.to(device)

# %%
vocab_size = len(idx_to_char)
embed_dim = 256
rnn_hidden_size = 512

torch.manual_seed(1)
model = RNNModel(vocab_size, embed_dim, rnn_hidden_size)
model = model.to(device)

model
# Out:
# RNNModel(
#   (embedding): Embedding(85, 256)
#   (rnn): LSTM(256, 512, batch_first=True)
#   (fc): Linear(in_features=512, out_features=85, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.005)

num_epochs = 2000

# %%
for epoch in range(num_epochs):
    hidden, cell = model.init_hidden(batch_size)
    
    seq_batch, target_batch = next(iter(dataloader))
        
    seq_batch = seq_batch.to(device)
    target_batch = target_batch.to(device)
    
    optimizer.zero_grad()
    
    loss = 0
    
    hidden, cell = model.init_hidden(batch_size)

    logits, _ = model(seq_batch, hidden, cell)
    
    loss += criterion(logits.view(logits.size(0) * logits.size(1), -1), target_batch.view(-1))
    
    loss.backward()
    
    optimizer.step()
    
    loss = loss.item()
    
    if epoch % 100 == 0:
        print(f'Epoch {epoch} loss: {loss:.4f}')
# Out:
# Epoch 0 loss: 1.2037
# Epoch 100 loss: 1.2078
# Epoch 200 loss: 1.1990
# Epoch 300 loss: 1.2514
# Epoch 400 loss: 1.2090
# Epoch 500 loss: 1.2288
# Epoch 600 loss: 1.1358
# Epoch 700 loss: 1.1678
# Epoch 800 loss: 1.2074
# Epoch 900 loss: 1.1567
# Epoch 1000 loss: 1.1091
# Epoch 1100 loss: 1.1502
# Epoch 1200 loss: 1.1952
# Epoch 1300 loss: 1.1738
# Epoch 1400 loss: 1.1984
# Epoch 1500 loss: 1.1307
# Epoch 1600 loss: 1.1628
# Epoch 1700 loss: 1.1798
# Epoch 1800 loss: 1.2049
# Epoch 1900 loss: 1.1969

# %% [markdown]
# ### Random Decoding

# %%
# Random Decoding
from torch.distributions.categorical import Categorical

def random_sample(model, starting_str, len_generated_text=500, temperature=1.0):

    encoded_input = torch.tensor([char_to_idx[s] for s in starting_str])
    encoded_input = torch.reshape(encoded_input, (1, -1))

    generated_str = starting_str
    model.eval()
    
    hidden, cell = model.init_hidden(1)
    hidden = hidden.to(device)
    cell = cell.to(device)
        
    for c in range(len(starting_str)-1):
        out = encoded_input[:, c].reshape(1, 1)
        _, (hidden, cell) = model(out, hidden, cell)
    
    last_char = encoded_input[:, -1]
    for i in range(len_generated_text):
        logits, (hidden, cell) = model(last_char.reshape(1, 1), hidden, cell)
        logits = torch.squeeze(logits, 0)
        
        logits /= temperature
        m = Categorical(logits=logits)
        last_char = m.sample()
        generated_str += str(idx_to_char[last_char])
        
    return generated_str

# %%
torch.manual_seed(1)
model.to(device)
print(random_sample(model, starting_str='The island'))
# Out:
# The island?
# Superb, which had crossed one open.
# House was a gairs on the river, and you.
#
# “There is that which was so as still retreat.
#
# This was to leave nothing. It was a swell where the reporter could see this unfortunate for
# be recognized at possessioners, middles almost savory, and round the channel one. But the Serpending by
# viterary thrown with earthquestion; the boat, Herbert had kept succeeded, fermed his line. Ayrton
# did not mode a leaf anything hust to the summit of convictions. It was there, a

# %% [markdown]
# ### Beam search

# %%
def init_hidden(model, batch_size):
    return (
        torch.zeros(1, batch_size, model.rnn_hidden_size),
        torch.zeros(1, batch_size, model.rnn_hidden_size)
    )

# %%
def beam_search_decoding(model, starting_str, len_generated_text=500, beams=5, print_paths=True):
    assert(len(starting_str) != 0)

    encoded_input = torch.tensor([char_to_idx[s] for s in starting_str])
    encoded_input = torch.reshape(encoded_input, (1, -1))

    model.eval()
    
    hidden, cell = init_hidden(model, 1)
    hidden = hidden.to(device)
    cell = cell.to(device)
    
    generated_log_prob = 0
    generated_str = starting_str[0]
        
    for i in range(len(starting_str)-1):
        out = encoded_input[:, i].reshape(1, 1)
        logits, (hidden, cell) = model(out, hidden, cell)
        
        generated_str += starting_str[i+1]
        probs = nn.Softmax(dim=1)(logits.squeeze(1)).squeeze()
        generated_log_prob += np.log(probs[char_to_idx[generated_str[i+1]]].item())
        
    last_char_int = encoded_input[:, -1].reshape(1,1)
    
    logits, (hidden, cell) = model(last_char_int, hidden, cell)
                        
    probs = nn.Softmax(dim=1)(logits.squeeze(1)).squeeze()
    
    new_beams = []
    
    for j, prob in enumerate(probs):
        new_beams.append(
            (
                hidden,
                cell,
                generated_str + idx_to_char[j],
                generated_log_prob + np.log(prob.item())
            )
        )
        
    new_beams = sorted(new_beams, key = lambda beam_data: -beam_data[-1])
    
    beam_to_beam_data = {}
    
    for beam in range(beams):
        beam_to_beam_data[beam] = new_beams[beam]
    
    print('The number of beams is', len(beam_to_beam_data))
        
    for i in range(len_generated_text):
        new_beams = []
        
        for beam in range(beams):
            
            (hidden, cell, generated_str, generated_log_prob) = beam_to_beam_data[beam]
                        
            last_char_int = torch.tensor(char_to_idx[generated_str[-1]]).reshape(1, 1)
            
            logits, (hidden, cell) = model(last_char_int, hidden, cell)
            
            probs = nn.Softmax(dim=1)(logits.squeeze(1)).squeeze()
                                                
            for j, prob in enumerate(probs):
                new_beams.append(
                    (
                        hidden,
                        cell,
                        generated_str + idx_to_char[j],
                        generated_log_prob + np.log(prob.item())
                    )
                )
        
        new_beams = sorted(new_beams, key = lambda beam_data: -beam_data[-1])
                
        assert(len(new_beams) == beams * len(char_to_idx))
        
        if print_paths:
            print("The first 5 paths beam paths and the associated data for them: ")
            for beam in range(5):
                generated_str, generated_log_prob = new_beams[beam][2:]
                print("Text: \"{}\" Prob {:0.30f}".format(
                        generated_str, np.exp(generated_log_prob)
                ))
            _ = input("Insert anything to continue ...")
            print("\n")
                
        for beam in range(beams):
            beam_to_beam_data[beam] = new_beams[beam]
            
    generated_strs = []
    generated_log_probs = []
        
    for beam in range(beams):
        (_, _, generated_str, generated_log_prob) = beam_to_beam_data[beam]
        generated_strs.append(generated_str)
        generated_log_probs.append(generated_log_prob)        
                
    return generated_strs, [np.exp(_) for _ in generated_log_probs]

# %%
model.to(device)
beams = 5
len_generated_text = 500

generated_strs, generated_probs = beam_search_decoding(
    model,
    starting_str="The island",
    len_generated_text=len_generated_text,
    beams=beams
)

for beam in range(beams):
    print(f"Beam {beam} information: ")
    print(generated_strs[beam])
    print(generated_probs[beam])
# Out:
# The number of beams is 5
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, " Prob 0.001224591919526377701080144256
# Text: "The island w" Prob 0.000742109791642601751733565596
# Text: "The island?”" Prob 0.000375831776073952416889617512
# Text: "The island i" Prob 0.000372457092760443994692437508
# Text: "The island o" Prob 0.000252795300040132653405372531
# The first 5 paths beam paths and the associated data for them:
# Text: "The island wa" Prob 0.000478577996922212583075922909
# Text: "The island, a" Prob 0.000441835097894723862702731632
# Text: "The island is" Prob 0.000336136278199693867493880184
# Text: "The island?” " Prob 0.000189226141215010463473428226
# Text: "The island?”
# " Prob 0.000186338308712591193107635523
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was" Prob 0.000475132975728690461637154785
# Text: "The island, an" Prob 0.000356716189444643489488834254
# Text: "The island is " Prob 0.000289652316871872813914406963
# Text: "The island?”
#
# " Prob 0.000169878007315161648656254290
# Text: "The island?” a" Prob 0.000160107018773822710154541848
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island was " Prob 0.000411057288850606998738268505
# Text: "The island, and" Prob 0.000348683172705367011318805526
# Text: "The island?” as" Prob 0.000152425931668267685727136129
# Text: "The island?”
#
# “" Prob 0.000144620681627687271142423953
# Text: "The island is n" Prob 0.000061350007779257856289044371
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island, and " Prob 0.000308967741643058541912980619
# Text: "The island?” ask" Prob 0.000149677403248657200397764289
# Text: "The island was n" Prob 0.000073394758730764599594965925
# Text: "The island was t" Prob 0.000060834004940627321429778146
# Text: "The island was a" Prob 0.000055510450367738771047711882
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” aske" Prob 0.000149410910064541298594709140
# Text: "The island, and t" Prob 0.000088177175334567021330357817
# Text: "The island was no" Prob 0.000062933145803324128152514416
# Text: "The island, and i" Prob 0.000041780507543267101646603662
# Text: "The island, and a" Prob 0.000041362194695087337644595626
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked" Prob 0.000148923694457451204209430529
# Text: "The island, and th" Prob 0.000079212614762757505254379964
# Text: "The island was not" Prob 0.000048226233717677395346386249
# Text: "The island, and it" Prob 0.000022403586679069009213530195
# Text: "The island, and in" Prob 0.000010240503526453202350673249
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked " Prob 0.000139473317493278749093846280
# Text: "The island, and the" Prob 0.000051504453624326171985899070
# Text: "The island was not " Prob 0.000031677535771872602121841667
# Text: "The island, and it " Prob 0.000019949000027115298250670120
# Text: "The island, and tha" Prob 0.000017140102314826792398796962
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked t" Prob 0.000065894603639719755519034428
# Text: "The island, and the " Prob 0.000024670446132384401546162531
# Text: "The island?” asked G" Prob 0.000023002031276742752722869884
# Text: "The island?” asked H" Prob 0.000021968240291383941975317945
# Text: "The island, and that" Prob 0.000016515839567117904842499451
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked th" Prob 0.000065342984497259823275898405
# Text: "The island?” asked Gi" Prob 0.000021001225819054151181973153
# Text: "The island, and that " Prob 0.000014893094806946382901253687
# Text: "The island?” asked He" Prob 0.000013427583698356850675534151
# Text: "The island?” asked Ha" Prob 0.000008376092668753812127608628
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the" Prob 0.000063803644807184032032749965
# Text: "The island?” asked Gid" Prob 0.000020981111117205732602203003
# Text: "The island?” asked Her" Prob 0.000013386558744467345484605199
# Text: "The island?” asked Har" Prob 0.000008188159473454094007126465
# Text: "The island, and that t" Prob 0.000004407720084320055388144976
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the " Prob 0.000050413026779010209092388162
# Text: "The island?” asked Gide" Prob 0.000020705570158880085837116783
# Text: "The island?” asked Herb" Prob 0.000013296169318664626671287581
# Text: "The island?” asked the
# " Prob 0.000012071638123126969476222974
# Text: "The island?” asked Hard" Prob 0.000008159456627475761335364229
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideo" Prob 0.000020555292874736743046230544
# Text: "The island?” asked the e" Prob 0.000019409106477084707431668420
# Text: "The island?” asked the r" Prob 0.000015413239684741150058123679
# Text: "The island?” asked Herbe" Prob 0.000013218546588891301178550312
# Text: "The island?” asked the s" Prob 0.000008730854704364772762435927
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon" Prob 0.000020489756186697294452472504
# Text: "The island?” asked the en" Prob 0.000018974905470773607840673236
# Text: "The island?” asked the re" Prob 0.000015201458967451345714459905
# Text: "The island?” asked Herber" Prob 0.000013214663094982869118382621
# Text: "The island?” asked the sa" Prob 0.000007981566861215177619785083
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the eng" Prob 0.000018723377262692009886935196
# Text: "The island?” asked Gideon " Prob 0.000018020703351214747501077285
# Text: "The island?” asked the rep" Prob 0.000014880273499414027344595057
# Text: "The island?” asked Herbert" Prob 0.000013151458483121531074138202
# Text: "The island?” asked the sai" Prob 0.000007888431067649257400105356
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the engi" Prob 0.000018601434147294337802290912
# Text: "The island?” asked Gideon S" Prob 0.000017860395592623842542798554
# Text: "The island?” asked the repo" Prob 0.000014642596630303040492479885
# Text: "The island?” asked the sail" Prob 0.000007721273900111924246274925
# Text: "The island?” asked Herbert," Prob 0.000006905876219670981859045412
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the engin" Prob 0.000018466454911409200509474562
# Text: "The island?” asked Gideon Sp" Prob 0.000017841364408188399223991610
# Text: "The island?” asked the repor" Prob 0.000014547610804343259332258378
# Text: "The island?” asked the sailo" Prob 0.000007541468608142821796499859
# Text: "The island?” asked Herbert, " Prob 0.000006332617253143763465250433
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the engine" Prob 0.000018362961763946581008428646
# Text: "The island?” asked Gideon Spi" Prob 0.000017279422368019338538541740
# Text: "The island?” asked the report" Prob 0.000014492958899415999128893959
# Text: "The island?” asked the sailor" Prob 0.000007538732012220922287207454
# Text: "The island?” asked Herbert, “" Prob 0.000004592141871771122273648488
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the enginee" Prob 0.000018319559754591299537010776
# Text: "The island?” asked Gideon Spil" Prob 0.000017176837868533749507753139
# Text: "The island?” asked the reporte" Prob 0.000014288723714758747902623184
# Text: "The island?” asked the sailor," Prob 0.000004515997318788696363327153
# Text: "The island?” asked the sailor." Prob 0.000001284818604993497124711261
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked the engineer" Prob 0.000018286729761606667482836536
# Text: "The island?” asked Gideon Spile" Prob 0.000017089769202143947457016998
# Text: "The island?” asked the reporter" Prob 0.000014286805744232189340175813
# Text: "The island?” asked the sailor, " Prob 0.000004125647848424852956006163
# Text: "The island?” asked the sailor.
# " Prob 0.000000714442380741764633574737
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilet" Prob 0.000017073769586661962505266463
# Text: "The island?” asked the engineer," Prob 0.000010693835501090356320300599
# Text: "The island?” asked the reporter." Prob 0.000006625907316763702079736881
# Text: "The island?” asked the reporter," Prob 0.000005564996423346270798006557
# Text: "The island?” asked the engineer." Prob 0.000004489026984654597412637434
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett" Prob 0.000017043555804753298532757885
# Text: "The island?” asked the engineer, " Prob 0.000009692190984472248441671492
# Text: "The island?” asked the reporter, " Prob 0.000005221813346993046656130660
# Text: "The island?” asked the reporter.
# " Prob 0.000004812256684810639820854515
# Text: "The island?” asked the engineer.
# " Prob 0.000003397241822639380428580170
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett," Prob 0.000008027290543835051978417520
# Text: "The island?” asked the engineer, “" Prob 0.000005946889372025848653996547
# Text: "The island?” asked Gideon Spilett " Prob 0.000005205495323739697402585635
# Text: "The island?” asked the reporter.
#
# " Prob 0.000004710332065632821900967326
# Text: "The island?” asked the engineer.
#
# " Prob 0.000003334937651200910635647390
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett, " Prob 0.000006722603488653017263329981
# Text: "The island?” asked the reporter.
#
# “" Prob 0.000003266380491000348379969625
# Text: "The island?” asked the engineer.
#
# “" Prob 0.000002219256644913358522518002
# Text: "The island?” asked Gideon Spilett a" Prob 0.000001788568659161643360612308
# Text: "The island?” asked the engineer, “w" Prob 0.000001189727214654504957620914
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett, “" Prob 0.000003833455880243788635680733
# Text: "The island?” asked Gideon Spilett an" Prob 0.000001195712742520473686631539
# Text: "The island?” asked Gideon Spilett, a" Prob 0.000000783430171098168848437850
# Text: "The island?” asked the engineer, “wh" Prob 0.000000738422341743103419904571
# Text: "The island?” asked the reporter.
#
# “W" Prob 0.000000677411714813553016512960
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and" Prob 0.000001158325908466994412697004
# Text: "The island?” asked Gideon Spilett, “a" Prob 0.000000857523523188240935940900
# Text: "The island?” asked Gideon Spilett, “w" Prob 0.000000659223051022923410822193
# Text: "The island?” asked Gideon Spilett, an" Prob 0.000000629115466402738677955222
# Text: "The island?” asked Gideon Spilett, “t" Prob 0.000000497650803916049682033645
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and " Prob 0.000001065696309088359378531565
# Text: "The island?” asked Gideon Spilett, “an" Prob 0.000000750090247848641579893033
# Text: "The island?” asked Gideon Spilett, and" Prob 0.000000613109133079808285185063
# Text: "The island?” asked Gideon Spilett, “th" Prob 0.000000455549263329822770739901
# Text: "The island?” asked Gideon Spilett, “wh" Prob 0.000000442505428206665340363894
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett, “and" Prob 0.000000733166065517013094935566
# Text: "The island?” asked Gideon Spilett, and " Prob 0.000000546298164088649593364913
# Text: "The island?” asked Gideon Spilett, “wha" Prob 0.000000266815257944755776789642
# Text: "The island?” asked Gideon Spilett and H" Prob 0.000000261130981698901464381902
# Text: "The island?” asked Gideon Spilett, “tha" Prob 0.000000212876771382922258268685
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett, “and " Prob 0.000000669747034090198698267054
# Text: "The island?” asked Gideon Spilett, “what" Prob 0.000000265177363825985726359009
# Text: "The island?” asked Gideon Spilett and He" Prob 0.000000242764014829674635244827
# Text: "The island?” asked Gideon Spilett, “that" Prob 0.000000210999414535381271380252
# Text: "The island?” asked Gideon Spilett, and H" Prob 0.000000108025131108322108570473
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Her" Prob 0.000000240205989062251058750188
# Text: "The island?” asked Gideon Spilett, “what " Prob 0.000000215435254469336977029933
# Text: "The island?” asked Gideon Spilett, “that " Prob 0.000000190393374132402747192445
# Text: "The island?” asked Gideon Spilett, “and t" Prob 0.000000140635116317708359343875
# Text: "The island?” asked Gideon Spilett, “and i" Prob 0.000000134539925917819548502918
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herb" Prob 0.000000237778661264382450635983
# Text: "The island?” asked Gideon Spilett, “and th" Prob 0.000000129522897333588876313265
# Text: "The island?” asked Gideon Spilett, “that i" Prob 0.000000067022144190195328129841
# Text: "The island?” asked Gideon Spilett, “and if" Prob 0.000000066365705431535574840612
# Text: "The island?” asked Gideon Spilett, “what w" Prob 0.000000063869207366438944246941
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbe" Prob 0.000000237597675723971838389258
# Text: "The island?” asked Gideon Spilett, “and the" Prob 0.000000063433985374358621354777
# Text: "The island?” asked Gideon Spilett, “and if " Prob 0.000000059130963569343081969361
# Text: "The island?” asked Gideon Spilett, “and tha" Prob 0.000000044375882518952637201074
# Text: "The island?” asked Gideon Spilett, “what wo" Prob 0.000000029672360129873541712977
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herber" Prob 0.000000237567114289690392166899
# Text: "The island?” asked Gideon Spilett, “and that" Prob 0.000000043720943976219179653836
# Text: "The island?” asked Gideon Spilett, “what wou" Prob 0.000000028744177429752210419739
# Text: "The island?” asked Gideon Spilett, “and the " Prob 0.000000023445543044217614834641
# Text: "The island?” asked Gideon Spilett, “and ther" Prob 0.000000017716647326162449737009
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert" Prob 0.000000237507910897134260591970
# Text: "The island?” asked Gideon Spilett, “and that " Prob 0.000000039545789607904638498079
# Text: "The island?” asked Gideon Spilett, “what woul" Prob 0.000000028564165845339758038792
# Text: "The island?” asked Gideon Spilett, “and there" Prob 0.000000017624171778392978341185
# Text: "The island?” asked Gideon Spilett, “and the c" Prob 0.000000003604610805791442059771
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert " Prob 0.000000135691914802182579898092
# Text: "The island?” asked Gideon Spilett and Herbert," Prob 0.000000066621795920485126603081
# Text: "The island?” asked Gideon Spilett, “what would" Prob 0.000000028530766785484552842446
# Text: "The island?” asked Gideon Spilett and Herbert
# " Prob 0.000000020067059603241892311078
# Text: "The island?” asked Gideon Spilett, “and that i" Prob 0.000000016037019606077808381037
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, " Prob 0.000000059711337877765422825821
# Text: "The island?” asked Gideon Spilett and Herbert w" Prob 0.000000035019459104782318121515
# Text: "The island?” asked Gideon Spilett, “what would " Prob 0.000000022538032648638256598990
# Text: "The island?” asked Gideon Spilett and Herbert r" Prob 0.000000018140320430361563669260
# Text: "The island?” asked Gideon Spilett and Herbert a" Prob 0.000000017316680222012804183888
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert wa" Prob 0.000000026733492524375426175532
# Text: "The island?” asked Gideon Spilett and Herbert re" Prob 0.000000016788203312521868186873
# Text: "The island?” asked Gideon Spilett and Herbert, a" Prob 0.000000015278782209426597332110
# Text: "The island?” asked Gideon Spilett and Herbert, w" Prob 0.000000014421135462954477120054
# Text: "The island?” asked Gideon Spilett and Herbert an" Prob 0.000000010760591259765926692198
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert was" Prob 0.000000022402870683040788031208
# Text: "The island?” asked Gideon Spilett and Herbert, wh" Prob 0.000000012015494627031492371246
# Text: "The island?” asked Gideon Spilett and Herbert, an" Prob 0.000000010466493137302278065543
# Text: "The island?” asked Gideon Spilett and Herbert and" Prob 0.000000010060938632209031836151
# Text: "The island?” asked Gideon Spilett and Herbert res" Prob 0.000000005030019978329333680948
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert was " Prob 0.000000016765482587658461841153
# Text: "The island?” asked Gideon Spilett and Herbert, who" Prob 0.000000009762712567300793194381
# Text: "The island?” asked Gideon Spilett and Herbert, and" Prob 0.000000009510099928907700108705
# Text: "The island?” asked Gideon Spilett and Herbert and " Prob 0.000000009405327929072398326463
# Text: "The island?” asked Gideon Spilett and Herbert was
# " Prob 0.000000004186131537927466852813
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and " Prob 0.000000008439806011170307379029
# Text: "The island?” asked Gideon Spilett and Herbert, who " Prob 0.000000004597892704333401288494
# Text: "The island?” asked Gideon Spilett and Herbert, whos" Prob 0.000000003374898991868110741302
# Text: "The island?” asked Gideon Spilett and Herbert and P" Prob 0.000000002514782278450739617821
# Text: "The island?” asked Gideon Spilett and Herbert was t" Prob 0.000000002227942262733486367672
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, whose" Prob 0.000000003342698561163495542865
# Text: "The island?” asked Gideon Spilett and Herbert and Pe" Prob 0.000000002446060820374288537461
# Text: "The island?” asked Gideon Spilett and Herbert, who w" Prob 0.000000001824386599824829921847
# Text: "The island?” asked Gideon Spilett and Herbert, and P" Prob 0.000000001808729714766321984018
# Text: "The island?” asked Gideon Spilett and Herbert, and H" Prob 0.000000001459485233863441289622
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, whose " Prob 0.000000002597926339071093309381
# Text: "The island?” asked Gideon Spilett and Herbert and Pen" Prob 0.000000002400229371878527976130
# Text: "The island?” asked Gideon Spilett and Herbert, and Pe" Prob 0.000000001744558423515764118136
# Text: "The island?” asked Gideon Spilett and Herbert, who wa" Prob 0.000000001280984872109097187910
# Text: "The island?” asked Gideon Spilett and Herbert, and He" Prob 0.000000001264549510952588876512
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert and Penc" Prob 0.000000002394983184962490623745
# Text: "The island?” asked Gideon Spilett and Herbert, and Pen" Prob 0.000000001720124105719856654422
# Text: "The island?” asked Gideon Spilett and Herbert, and Her" Prob 0.000000001236485194420062158849
# Text: "The island?” asked Gideon Spilett and Herbert, who was" Prob 0.000000001154875035433828889118
# Text: "The island?” asked Gideon Spilett and Herbert, whose p" Prob 0.000000000287700959358611530562
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert and Pencr" Prob 0.000000002390932736253353180753
# Text: "The island?” asked Gideon Spilett and Herbert, and Penc" Prob 0.000000001716591524625198709493
# Text: "The island?” asked Gideon Spilett and Herbert, and Herb" Prob 0.000000001226116157329918427465
# Text: "The island?” asked Gideon Spilett and Herbert, who was " Prob 0.000000000942841277008352151038
# Text: "The island?” asked Gideon Spilett and Herbert, who was
# " Prob 0.000000000143149639828124706478
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert and Pencro" Prob 0.000000002389608669372856115395
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencr" Prob 0.000000001714447577810247346677
# Text: "The island?” asked Gideon Spilett and Herbert, and Herbe" Prob 0.000000001225175296855244240940
# Text: "The island?” asked Gideon Spilett and Herbert, who was t" Prob 0.000000000129350712215882477156
# Text: "The island?” asked Gideon Spilett and Herbert, who was a" Prob 0.000000000107395366128242074648
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert and Pencrof" Prob 0.000000002388778007255865254081
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencro" Prob 0.000000001712407680216493730744
# Text: "The island?” asked Gideon Spilett and Herbert, and Herber" Prob 0.000000001224953224368503011228
# Text: "The island?” asked Gideon Spilett and Herbert, who was th" Prob 0.000000000070868235667228547750
# Text: "The island?” asked Gideon Spilett and Herbert, who was to" Prob 0.000000000049637236072244956223
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert and Pencro
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued tha" Prob 0.000000000000000000000106575689
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say t" Prob 0.000000000000000000000087948281
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to reach " Prob 0.000000000000000000000175102212
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that" Prob 0.000000000000000000000105402501
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, t" Prob 0.000000000000000000000092370230
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say th" Prob 0.000000000000000000000047759642
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say to" Prob 0.000000000000000000000039375580
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that " Prob 0.000000000000000000000098947040
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, th" Prob 0.000000000000000000000078095621
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to reach t" Prob 0.000000000000000000000044978125
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say to " Prob 0.000000000000000000000037890905
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say tha" Prob 0.000000000000000000000033734068
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to reach th" Prob 0.000000000000000000000043275560
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, the" Prob 0.000000000000000000000040523765
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that t" Prob 0.000000000000000000000039502763
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that" Prob 0.000000000000000000000033107685
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, tha" Prob 0.000000000000000000000029506980
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that th" Prob 0.000000000000000000000039171473
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to reach the" Prob 0.000000000000000000000037150456
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that " Prob 0.000000000000000000000031878534
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that" Prob 0.000000000000000000000027958648
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, the " Prob 0.000000000000000000000025530283
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to reach the " Prob 0.000000000000000000000033884174
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that the" Prob 0.000000000000000000000032911249
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that " Prob 0.000000000000000000000026829654
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that t" Prob 0.000000000000000000000010018823
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that i" Prob 0.000000000000000000000006043800
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that the " Prob 0.000000000000000000000022903207
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that i" Prob 0.000000000000000000000011270936
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that th" Prob 0.000000000000000000000009941657
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that t" Prob 0.000000000000000000000005598199
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they" Prob 0.000000000000000000000004906816
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the" Prob 0.000000000000000000000008163592
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that th" Prob 0.000000000000000000000005484015
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they " Prob 0.000000000000000000000004850005
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it" Prob 0.000000000000000000000004730070
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is" Prob 0.000000000000000000000004495067
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the " Prob 0.000000000000000000000005488113
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it " Prob 0.000000000000000000000004604139
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that the" Prob 0.000000000000000000000004340019
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is " Prob 0.000000000000000000000002903803
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they w" Prob 0.000000000000000000000001453053
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it w" Prob 0.000000000000000000000003192106
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that the " Prob 0.000000000000000000000003097775
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is t" Prob 0.000000000000000000000001935501
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the c" Prob 0.000000000000000000000001067114
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they we" Prob 0.000000000000000000000000996837
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is to" Prob 0.000000000000000000000001728701
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it wo" Prob 0.000000000000000000000001446771
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it wa" Prob 0.000000000000000000000001311208
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they wer" Prob 0.000000000000000000000000925386
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the co" Prob 0.000000000000000000000000653227
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is to " Prob 0.000000000000000000000001449875
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it wou" Prob 0.000000000000000000000001434257
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it was" Prob 0.000000000000000000000001300546
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they were" Prob 0.000000000000000000000000921033
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the col" Prob 0.000000000000000000000000250195
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it woul" Prob 0.000000000000000000000001433193
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it was " Prob 0.000000000000000000000001274785
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is to s" Prob 0.000000000000000000000000960477
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been continued that they were " Prob 0.000000000000000000000000884454
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the colo" Prob 0.000000000000000000000000235173
#
#
# The first 5 paths beam paths and the associated data for them:
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it would" Prob 0.000000000000000000000001432805
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that is to sa" Prob 0.000000000000000000000000900226
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it was n" Prob 0.000000000000000000000000233351
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say, that it was t" Prob 0.000000000000000000000000220374
# Text: "The island?” asked Gideon Spilett and Herbert, and Pencroft,” replied the reporter.
#
# “Well,” replied the engineer, “what would have been able to say that the colon" Prob 0.000000000000000000000000219285
